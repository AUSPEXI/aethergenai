# %%
# Dementia Target Triage (Public Anchors)
# Research-only scaffold; no PHI. Records citations and hashes.
from hashlib import sha256
import json, time

anchors = {
  "genetics": ["APOE","TREM2","SORL1","BIN1","CLU","PICALM","CD33","ABCA7","MAPT","APP","PSEN1","PSEN2"],
  "pathways": ["complement","microglia activation","autophagy-lysosome","mitochondrial","synaptic"],
}

run = {
  "generatedAt": time.strftime('%Y-%m-%dT%H:%M:%SZ', time.gmtime()),
  "inputs": anchors,
}

print("Loaded anchor lists (public).")

# TODO: fetch evidence snippets (Open Targets, Reactome, AMP-AD/ROSMAP refs)
# scoring: simple placeholder weights to demonstrate structure
weights = {
  "genetic_support": 0.5,
  "expression_support": 0.3,
  "pathway_centrality": 0.2,
}

candidates = [
  {"target": "TREM2", "genetic_support": 0.9, "expression_support": 0.7, "pathway_centrality": 0.6},
  {"target": "SORL1", "genetic_support": 0.8, "expression_support": 0.6, "pathway_centrality": 0.7},
  {"target": "CD33",  "genetic_support": 0.7, "expression_support": 0.5, "pathway_centrality": 0.6},
]

for c in candidates:
  c["score"] = sum(c[k]*weights[k] for k in weights)

shortlist = sorted(candidates, key=lambda x: x["score"], reverse=True)
print("Shortlist:")
for c in shortlist:
  print(c)

run["outputs"] = shortlist
run_json = json.dumps(run, sort_keys=True).encode()
print("Signed metrics (sha256):", sha256(run_json).hexdigest())

# %%
# Dementia Target Triage (Public Anchors)
# Research-only scaffold; no PHI. Records citations and hashes.
from hashlib import sha256
import json, time

anchors = {
  "genetics": ["APOE","TREM2","SORL1","BIN1","CLU","PICALM","CD33","ABCA7","MAPT","APP","PSEN1","PSEN2"],
  "pathways": ["complement","microglia activation","autophagy-lysosome","mitochondrial","synaptic"],
}

run = {
  "generatedAt": time.strftime('%Y-%m-%dT%H:%M:%SZ', time.gmtime()),
  "inputs": anchors,
}

print("Loaded anchor lists (public).")

# TODO: fetch evidence snippets (Open Targets, Reactome, AMP-AD/ROSMAP refs)
# scoring: simple placeholder weights to demonstrate structure
weights = {
  "genetic_support": 0.5,
  "expression_support": 0.3,
  "pathway_centrality": 0.2,
}

candidates = [
  {"target": "TREM2", "genetic_support": 0.9, "expression_support": 0.7, "pathway_centrality": 0.6},
  {"target": "SORL1", "genetic_support": 0.8, "expression_support": 0.6, "pathway_centrality": 0.7},
  {"target": "CD33",  "genetic_support": 0.7, "expression_support": 0.5, "pathway_centrality": 0.6},
]

for c in candidates:
  c["score"] = sum(c[k]*weights[k] for k in weights)

shortlist = sorted(candidates, key=lambda x: x["score"], reverse=True)
print("Shortlist:")
for c in shortlist:
  print(c)

run["outputs"] = shortlist
run_json = json.dumps(run, sort_keys=True).encode()
print("Signed metrics (sha256):", sha256(run_json).hexdigest())
